# %%
import pandas as pd

df_exames = pd.read_csv(r'C:\Users\emess\OneDrive\Documentos\5º periodo\TABD\projeto\bases\educacao\exames_tecnico.csv', sep=';')
df_exames = df_exames.sort_values(by=['CAMPUS', 'CURSO/TURNO/INTEGRADO'])
df_exames
# Out:
#                           CAMPUS      CURSO/TURNO/INTEGRADO       Turno  \
# 2               CAMPUS ARAPIRACA           Eletroeletrônica  Vespertino
# 3               CAMPUS ARAPIRACA           Eletroeletrônica    Matutino
# 0               CAMPUS ARAPIRACA                Informática  Vespertino
# 1               CAMPUS ARAPIRACA                Informática    Matutino
# 4                 CAMPUS BATALHA              Agroindústria  Vespertino
# ..                           ...                        ...         ...
# 78  CAMPUS SÃO MIGUEL DOS CAMPOS  Informática para Internet  Vespertino
# 89                 CAMPUS VIÇOSA             Administração   Vespertino
# 87                 CAMPUS VIÇOSA  Informática para Internet  Vespertino
# 88                 CAMPUS VIÇOSA  Informática para Internet    Matutino
# 90                         TOTAL                        NaN         NaN
#
#        Código  VAGAS 2024.1  INSCRITOS 2024.1  VAGAS 2023.1  INSCRITOS 2023.1  \
# ...

# %%
df_ideb = pd.read_csv(r'C:\Users\emess\OneDrive\Documentos\5º periodo\TABD\projeto\bases\educacao\ideb_municipios.csv', sep=',')
df_federal = df_ideb[df_ideb['ensino_rede'] == 'Federal']
df_federal = df_federal.sort_values(by=['ano', 'no_mun'])
df_federal
# Out:
#        _id   co_mun                 no_mun   ano variavel ensino_rede  \
# 159    160  2700300              Arapiraca  2017     IDEB     Federal
# 377    378  2700706                Batalha  2017     IDEB     Federal
# 1304  1305  2702306               Coruripe  2017     IDEB     Federal
# 2529  2530  2704302                 Maceió  2017     IDEB     Federal
# 2645  2646  2704500               Maragogi  2017     IDEB     Federal
# 2759  2760  2704708       Marechal Deodoro  2017     IDEB     Federal
# 3213  3214  2705507                 Murici  2017     IDEB     Federal
# 3669  3670  2706307    Palmeira dos Índios  2017     IDEB     Federal
# 4023  4024  2706703                 Penedo  2017     IDEB     Federal
# 4239  4240  2707107               Piranhas  2017     IDEB     Federal
# 6293  6294  2708006     Santana do Ipanema  2017     IDEB     Federal
# 5245  5246  2708907                 Satuba  2017     IDEB     Federal
# ...

# %%
df_matricula = pd.read_csv(r'C:\Users\emess\OneDrive\Documentos\5º periodo\TABD\projeto\bases\educacao\matricula.csv', sep=',')
df_federal = df_matricula[df_matricula['ensino_rede'] == 'Federal']
df_ensino_medio = df_federal[df_federal['ensino_tipo'] == 'Ensino Médio']
df_ensino_medio
# Out:
#          _id   co_mun                 no_mun   ano   variavel ensino_rede  \
# 838      839  2700300              Arapiraca  2011  Matrícula     Federal
# 868      869  2700300              Arapiraca  2012  Matrícula     Federal
# 898      899  2700300              Arapiraca  2013  Matrícula     Federal
# 928      929  2700300              Arapiraca  2014  Matrícula     Federal
# 958      959  2700300              Arapiraca  2015  Matrícula     Federal
# ...      ...      ...                    ...   ...        ...         ...
# 40008  40009  2707701              Rio Largo  2023  Matrícula     Federal
# 40073  40074  2708006     Santana do Ipanema  2023  Matrícula     Federal
# 40223  40224  2708600  São Miguel dos Campos  2023  Matrícula     Federal
# 40303  40304  2708907                 Satuba  2023  Matrícula     Federal
# 40473  40474  2709400                 Viçosa  2023  Matrícula     Federal
#
#         ensino_tipo  valor
# 838    Ensino Médio  283.0
# ...

# %%
df_rendimentos = pd.read_csv(r'C:\Users\emess\OneDrive\Documentos\5º periodo\TABD\projeto\bases\educacao\rendimento.csv', sep=',')
df_federal = df_rendimentos[df_rendimentos['ensino_rede'] == 'Federal']
df_ensino_medio = df_federal[df_federal['ensino_tipo'] == 'Ensino Médio']
df_ensino_medio
# Out:
#          _id   co_mun     no_mun   ano            variavel ensino_rede  \
# 999     1000  2700300  Arapiraca  2011    Taxa de Abandono     Federal
# 1011    1012  2700300  Arapiraca  2011   Taxa de Aprovação     Federal
# 1023    1024  2700300  Arapiraca  2011  Taxa de Reprovação     Federal
# 1035    1036  2700300  Arapiraca  2012    Taxa de Abandono     Federal
# 1047    1048  2700300  Arapiraca  2012   Taxa de Aprovação     Federal
# ...      ...      ...        ...   ...                 ...         ...
# 47667  47668  2708907     Satuba  2023   Taxa de Aprovação     Federal
# 47679  47680  2708907     Satuba  2023  Taxa de Reprovação     Federal
# 47853  47854  2709400     Viçosa  2023    Taxa de Abandono     Federal
# 47865  47866  2709400     Viçosa  2023   Taxa de Aprovação     Federal
# 47877  47878  2709400     Viçosa  2023  Taxa de Reprovação     Federal
#
#         ensino_tipo  valor
# 999    Ensino Médio    8.5
# 1011   Ensino Médio   71.3
# 1023   Ensino Médio   20.2
# ...
